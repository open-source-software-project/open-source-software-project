# %% [markdown]
# # Number of slugs by gender

# %%
user_node.groupby('gender_updated')['number_slugs'].describe()
# Out:
#                  count       mean        std  min  25%  50%   75%     max
# gender_updated
# female           185.0  10.470270  37.252523  1.0  1.0  4.0   9.0   483.0
# male            1086.0  17.151934  76.399580  1.0  3.0  6.0  15.0  2020.0
# other             39.0   6.025641   8.044243  1.0  1.0  3.0   6.0    42.0
# unknown          170.0   7.970588  11.688474  1.0  2.0  4.0   8.0    73.0

# %%
plt.ticklabel_format(style='plain', axis='x')
seaborn.boxplot(x='gender_updated', y='number_slugs', 
            data=user_node)
# Out:
# <AxesSubplot:xlabel='gender_updated', ylabel='number_slugs'>

# %%
ax = seaborn.histplot(x='number_slugs',data=user_node,hue='gender_updated')
ax.set_xscale('log')
ax.set_yscale('log')
plt.show()

# %%
seaborn.kdeplot(x='number_slugs',data=user_node,hue='gender_updated')
plt.show()

# %% [markdown]
# **Subset to the population between 5th and 95th quantiles**

# %%
number_slugs.groupby('gender_updated')['number_slugs'].describe()
# Out:
#                 count       mean        std  min  25%   50%    75%   max
# gender_updated
# female           65.0  12.984615   8.697148  6.0  7.0  10.0  16.00  47.0
# male            515.0  15.912621   9.991345  6.0  8.0  13.0  20.00  51.0
# other            12.0  14.416667  10.326122  6.0  7.5  11.5  17.00  42.0
# unknown          62.0  14.725806  10.544472  6.0  7.0  11.0  16.75  46.0

# %%
plt.ticklabel_format(style='plain', axis='x')
seaborn.boxplot(x='gender_updated', y='number_slugs', 
            data=number_slugs)
# Out:
# <AxesSubplot:xlabel='gender_updated', ylabel='number_slugs'>

# %%
ax = seaborn.histplot(x='number_slugs',data=number_slugs,hue='gender_updated')
plt.show()

# %%
seaborn.kdeplot(x='number_slugs',data=number_slugs,hue='gender_updated')
plt.show()

# %% [markdown]
# # Number of commits by gender

# %%
user_node.groupby('gender_updated')['number_commits'].describe()
# Out:
#                  count        mean          std  min    25%    50%     75%  \
# gender_updated
# female           185.0  383.994595  1297.765695  1.0  15.00   66.0  291.00
# male            1086.0  611.187845  1322.171883  1.0  42.00  167.0  551.25
# other             39.0  285.948718   633.138671  2.0  23.00   55.0  248.50
# unknown          170.0  310.511765   713.721758  1.0  28.25   87.5  255.50
#
#                     max
# gender_updated
# female          13688.0
# male            18121.0
# other            3411.0
# unknown          4967.0

# %%
plt.ticklabel_format(style='plain', axis='x')
seaborn.boxplot(x='gender_updated', y='number_commits', 
            data=user_node)
# Out:
# <AxesSubplot:xlabel='gender_updated', ylabel='number_commits'>

# %%
ax = seaborn.histplot(x='number_commits',data=user_node,hue='gender_updated')
ax.set_xscale('log')
ax.set_yscale('log')
plt.show()

# %%
seaborn.kdeplot(x='number_commits',data=user_node,hue='gender_updated')
plt.show()

# %% [markdown]
# **Subset to the population between 5th and 95th quantiles**

# %%
number_commits.groupby('gender_updated')['number_commits'].describe()
# Out:
#                 count        mean         std    min    25%    50%     75%  \
# gender_updated
# female           62.0  506.725806  378.125106  122.0  204.0  367.0  707.50
# male            559.0  619.731664  533.188031  121.0  224.5  393.0  890.00
# other            11.0  614.454545  507.962669  176.0  268.5  402.0  832.50
# unknown          70.0  423.128571  384.842182  121.0  171.0  266.0  514.75
#
#                    max
# gender_updated
# female          1709.0
# male            2260.0
# other           1682.0
# unknown         2107.0

# %%
plt.ticklabel_format(style='plain', axis='x')
seaborn.boxplot(x='gender_updated', y='number_commits', 
            data=number_commits)
# Out:
# <AxesSubplot:xlabel='gender_updated', ylabel='number_commits'>

# %%
ax = seaborn.histplot(x='number_commits',data=number_commits,hue='gender_updated')
plt.show()

# %%
seaborn.kdeplot(x='number_commits',data=number_commits,hue='gender_updated')
plt.show()

# %% [markdown]
# # Number of additions by gender

# %%
user_node.groupby('gender_updated')['number_additions'].describe().round(1)
# Out:
#                  count       mean         std    min      25%       50%  \
# gender_updated
# female           185.0  2026532.3  12308593.4    0.0   1445.0   29491.0
# male            1086.0  1422974.8   5328611.7    0.0  13099.5  122162.5
# other             39.0   672802.3   2295155.6  125.0   7319.0   27019.0
# unknown          170.0  1171781.1   4047907.6    0.0   7936.8   67547.0
#
#                      75%          max
# gender_updated
# female          271713.0  149080533.0
# male            721692.2   97394457.0
# other           282055.0   13876413.0
# unknown         387783.5   41747156.0

# %%
plt.ticklabel_format(style='plain', axis='x')
seaborn.boxplot(x='gender_updated', y='number_additions', 
            data=user_node)
# Out:
# <AxesSubplot:xlabel='gender_updated', ylabel='number_additions'>

# %%
ax = seaborn.histplot(x='number_additions',data=user_node,hue='gender_updated')
ax.set_xscale('log')
ax.set_yscale('log')
plt.show()

# %%
seaborn.kdeplot(x='number_additions',data=user_node,hue='gender_updated')
plt.show()

# %% [markdown]
# **Subset to the population between 5th and 95th quantiles**

# %%
number_additions.groupby('gender_updated')['number_additions'].describe().round(1)
# Out:
#                 count       mean        std      min       25%       50%  \
# gender_updated
# female           58.0   751309.0   988289.5  82112.0  176425.0  353535.5
# male            560.0  1014269.7  1286239.0  74713.0  195666.2  427899.0
# other            13.0   922050.8  1088194.5  85397.0  278915.0  297897.0
# unknown          72.0   833082.2  1062214.3  76610.0  164527.8  318005.0
#
#                       75%        max
# gender_updated
# female           771184.0  4916128.0
# male            1260599.8  6512537.0
# other           1784837.0  3543041.0
# unknown         1005749.2  4115164.0

# %%
plt.ticklabel_format(style='plain', axis='x')
seaborn.boxplot(x='gender_updated', y='number_additions', 
            data=number_additions)
# Out:
# <AxesSubplot:xlabel='gender_updated', ylabel='number_additions'>

# %%
ax = seaborn.histplot(x='number_additions',data=number_additions,hue='gender_updated')
plt.show()

# %%
seaborn.kdeplot(x='number_additions',data=number_additions,hue='gender_updated')
plt.show()
